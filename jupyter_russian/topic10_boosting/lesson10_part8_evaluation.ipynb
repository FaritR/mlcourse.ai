# %% [markdown]
# <center>
# <img src="../../img/ods_stickers.jpg">
# ## Открытый курс по машинному обучению. Сессия № 2
# Автор материала: программист-исследователь Mail.ru Group, старший преподаватель Факультета Компьютерных Наук ВШЭ Юрий Кашницкий. Материал распространяется на условиях лицензии [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/). Можно использовать в любых целях (редактировать, поправлять и брать за основу), кроме коммерческих, но с обязательным упоминанием автора материала.

# %% [markdown]
# # <center>Тема 10. Бустинг
# ## <center>Часть 8. Оценка результатов Xgboost

# %% [markdown]
# ## Загрузка бибилиотек

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Загрузка и подготовка данных
#
# Посмотрим на примере данных по оттоку клиентов из телеком-компании.

# %%
df = pd.read_csv("../../data/telecom_churn.csv")

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False

# %% [markdown]
# **Штаты просто занумеруем, а признаки International plan (наличие международного роуминга), Voice mail plan (наличие голосовой почтыы) и целевой Churn сделаем бинарными.**

# %%
state_enc = LabelEncoder()
df["State"] = state_enc.fit_transform(df["State"])
df["International plan"] = (df["International plan"] == "Yes").astype("int")
df["Voice mail plan"] = (df["Voice mail plan"] == "Yes").astype("int")
df["Churn"] = (df["Churn"]).astype("int")

# %%
df.head()
# Out:
#    State  Account length  Area code  International plan  Voice mail plan  \
# 0     16             128        415                   0                1
# 1     35             107        415                   0                1
# 2     31             137        415                   0                0
# 3     35              84        408                   1                0
# 4     36              75        415                   1                0
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                       1      0
# 1                       1      0
# 2                       0      0
# 3                       2      0
# 4                       3      0

# %% [markdown]
# **Разделим данные на обучающую и тестовую выборки в отношении 7:3. Создадим соотв. объекты DMAtrix.**

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df.drop("Churn", axis=1), df["Churn"], test_size=0.3, random_state=42
)
dtrain = xgb.DMatrix(X_train, y_train)
dtest = xgb.DMatrix(X_test, y_test)

# %% [markdown]
# **Зададим параметры Xgboost.**

# %%
params = {"objective": "binary:logistic", "max_depth": 3, "silent": 1, "eta": 0.5}

num_rounds = 10

# %% [markdown]
# **Будем отслеживать качество модели и на обучающей выборке, и на валидационной.**

# %%
watchlist = [(dtest, "test"), (dtrain, "train")]

# %% [markdown]
# ## Использование встроенных метрик
# В Xgboost реализованы большинство популярных метрик для классификации, регрессии и ранжирования:
#
# - `rmse` - [root mean square error](https://www.wikiwand.com/en/Root-mean-square_deviation)
# - `mae` - [mean absolute error](https://en.wikipedia.org/wiki/Mean_absolute_error?oldformat=true)
# - `logloss` - [negative log-likelihood](https://en.wikipedia.org/wiki/Likelihood_function?oldformat=true)
# - `error` (по умолчанию) - доля ошибок в бинарной классификации
# - `merror` - доля ошибок в классификации на несколько классов
# - `auc` - [area under curve](https://en.wikipedia.org/wiki/Receiver_operating_characteristic?oldformat=true)
# - `ndcg` - [normalized discounted cumulative gain](https://en.wikipedia.org/wiki/Discounted_cumulative_gain?oldformat=true)
# - `map` - [mean average precision](https://en.wikipedia.org/wiki/Information_retrieval?oldformat=true)

# %%
xgb_model = xgb.train(params, dtrain, num_rounds, watchlist)
# Out:
# [18:44:58] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	test-logloss:0.43152	train-logloss:0.42606
# [1]	test-logloss:0.32608	train-logloss:0.31925
# [2]	test-logloss:0.26807	train-logloss:0.26154
# [3]	test-logloss:0.23736	train-logloss:0.23201
# [4]	test-logloss:0.21130	train-logloss:0.20370
# [5]	test-logloss:0.19646	train-logloss:0.19084
# [6]	test-logloss:0.18922	train-logloss:0.18075
# [7]	test-logloss:0.18332	train-logloss:0.17447
# [8]	test-logloss:0.18060	train-logloss:0.16928
# [9]	test-logloss:0.17848	train-logloss:0.16587
# /opt/homebrew/Caskroom/miniforge/base/envs/my_env/lib/python3.9/site-packages/xgboost/core.py:525: FutureWarning: Pass `evals` as keyword args.  Passing these as positional arguments will be considered as error in future releases.
#   warnings.warn(

# %% [markdown]
# **Чтоб отслеживать log_loss, просто добавим ее в словарь params.**

# %%
params["eval_metric"] = "logloss"
xgb_model = xgb.train(params, dtrain, num_rounds, watchlist)
# Out:
# [18:45:50] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	test-logloss:0.43152	train-logloss:0.42606
# [1]	test-logloss:0.32608	train-logloss:0.31925
# [2]	test-logloss:0.26807	train-logloss:0.26154
# [3]	test-logloss:0.23736	train-logloss:0.23201
# [4]	test-logloss:0.21130	train-logloss:0.20370
# [5]	test-logloss:0.19646	train-logloss:0.19084
# [6]	test-logloss:0.18922	train-logloss:0.18075
# [7]	test-logloss:0.18332	train-logloss:0.17447
# [8]	test-logloss:0.18060	train-logloss:0.16928
# [9]	test-logloss:0.17848	train-logloss:0.16587

# %% [markdown]
# **Можно отслеживать сразу несколько метрик.**

# %%
params
# Out:
# {'objective': 'binary:logistic',
#  'max_depth': 3,
#  'silent': 1,
#  'eta': 0.5,
#  'eval_metric': ['logloss', 'auc']}

# %%
params["eval_metric"] = ["logloss", "auc"]
xgb_model = xgb.train(params, dtrain, num_rounds, watchlist)
# Out:
# [18:46:12] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	test-logloss:0.43152	test-auc:0.83111	train-logloss:0.42606	train-auc:0.83474
# [1]	test-logloss:0.32608	test-auc:0.89705	train-logloss:0.31925	train-auc:0.88842
# [2]	test-logloss:0.26807	test-auc:0.90229	train-logloss:0.26154	train-auc:0.89562
# [3]	test-logloss:0.23736	test-auc:0.91246	train-logloss:0.23201	train-auc:0.90125
# [4]	test-logloss:0.21130	test-auc:0.91926	train-logloss:0.20370	train-auc:0.90869
# [5]	test-logloss:0.19646	test-auc:0.92112	train-logloss:0.19084	train-auc:0.91147
# [6]	test-logloss:0.18922	test-auc:0.92284	train-logloss:0.18075	train-auc:0.91454
# [7]	test-logloss:0.18332	test-auc:0.92410	train-logloss:0.17447	train-auc:0.91686
# [8]	test-logloss:0.18060	test-auc:0.93429	train-logloss:0.16928	train-auc:0.93381
# [9]	test-logloss:0.17848	test-auc:0.93483	train-logloss:0.16587	train-auc:0.93751

# %% [markdown]
# ## Создание собственной метрики качества
#
# **Чтобы создать свою метрику качества, достаточно определить функцию, принимающую 2 аргумента: вектор предсказанных вероятностей и объект `DMatrix` с истинными метками.
# В этом примере функция вернет просто число объектов, на которых классификатор ошибся, когда относил к классу 1 при превышении предсказанной вероятности класса 1 порога 0.5.
# Далее передаем эту функцию в xgb.train (параметр feval), если метрика тем лучше, чем меньше, надо дополнительно указать `maximize=False`.**

# %%
# custom evaluation metric
def misclassified(pred_probs, dmatrix):
    labels = dmatrix.get_label()  # obtain true labels
    preds = pred_probs > 0.5  # obtain predicted values
    return "misclassified", np.sum(labels != preds)

# %%
xgb_model = xgb.train(
    params, dtrain, num_rounds, watchlist, feval=misclassified, maximize=False
)
# Out:
# [18:48:27] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	test-logloss:0.43152	test-auc:0.83111	test-misclassified:99.00000	train-logloss:0.42606	train-auc:0.83474	train-misclassified:216.00000
# [1]	test-logloss:0.32608	test-auc:0.89705	test-misclassified:108.00000	train-logloss:0.31925	train-auc:0.88842	train-misclassified:228.00000
# [2]	test-logloss:0.26807	test-auc:0.90229	test-misclassified:86.00000	train-logloss:0.26154	train-auc:0.89562	train-misclassified:179.00000
# [3]	test-logloss:0.23736	test-auc:0.91246	test-misclassified:87.00000	train-logloss:0.23201	train-auc:0.90125	train-misclassified:177.00000
# [4]	test-logloss:0.21130	test-auc:0.91926	test-misclassified:77.00000	train-logloss:0.20370	train-auc:0.90869	train-misclassified:146.00000
# [5]	test-logloss:0.19646	test-auc:0.92112	test-misclassified:67.00000	train-logloss:0.19084	train-auc:0.91147	train-misclassified:125.00000
# [6]	test-logloss:0.18922	test-auc:0.92284	test-misclassified:72.00000	train-logloss:0.18075	train-auc:0.91454	train-misclassified:124.00000
# [7]	test-logloss:0.18332	test-auc:0.92410	test-misclassified:65.00000	train-logloss:0.17447	train-auc:0.91686	train-misclassified:112.00000
# [8]	test-logloss:0.18060	test-auc:0.93429	test-misclassified:63.00000	train-logloss:0.16928	train-auc:0.93381	train-misclassified:112.00000
# [9]	test-logloss:0.17848	test-auc:0.93483	test-misclassified:63.00000	train-logloss:0.16587	train-auc:0.93751	train-misclassified:109.00000
# /opt/homebrew/Caskroom/miniforge/base/envs/my_env/lib/python3.9/site-packages/xgboost/training.py:35: UserWarning: `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
#   warnings.warn(

# %% [markdown]
# **С помощью параметра evals_result можно сохранить значения метрик по итерациям.**

# %%
evals_result = {}
xgb_model = xgb.train(
    params,
    dtrain,
    num_rounds,
    watchlist,
    feval=misclassified,
    maximize=False,
    evals_result=evals_result,
)
# Out:
# [18:49:01] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	test-logloss:0.43152	test-auc:0.83111	test-misclassified:99.00000	train-logloss:0.42606	train-auc:0.83474	train-misclassified:216.00000
# [1]	test-logloss:0.32608	test-auc:0.89705	test-misclassified:108.00000	train-logloss:0.31925	train-auc:0.88842	train-misclassified:228.00000
# [2]	test-logloss:0.26807	test-auc:0.90229	test-misclassified:86.00000	train-logloss:0.26154	train-auc:0.89562	train-misclassified:179.00000
# [3]	test-logloss:0.23736	test-auc:0.91246	test-misclassified:87.00000	train-logloss:0.23201	train-auc:0.90125	train-misclassified:177.00000
# [4]	test-logloss:0.21130	test-auc:0.91926	test-misclassified:77.00000	train-logloss:0.20370	train-auc:0.90869	train-misclassified:146.00000
# [5]	test-logloss:0.19646	test-auc:0.92112	test-misclassified:67.00000	train-logloss:0.19084	train-auc:0.91147	train-misclassified:125.00000
# [6]	test-logloss:0.18922	test-auc:0.92284	test-misclassified:72.00000	train-logloss:0.18075	train-auc:0.91454	train-misclassified:124.00000
# [7]	test-logloss:0.18332	test-auc:0.92410	test-misclassified:65.00000	train-logloss:0.17447	train-auc:0.91686	train-misclassified:112.00000
# [8]	test-logloss:0.18060	test-auc:0.93429	test-misclassified:63.00000	train-logloss:0.16928	train-auc:0.93381	train-misclassified:112.00000
# [9]	test-logloss:0.17848	test-auc:0.93483	test-misclassified:63.00000	train-logloss:0.16587	train-auc:0.93751	train-misclassified:109.00000

# %%
evals_result
# Out:
# {'test': OrderedDict([('logloss',
#                [0.4315233405232429,
#                 0.3260817745625973,
#                 0.2680735386013985,
#                 0.2373635537661612,
#                 0.21130389650538564,
#                 0.19646011152490975,
#                 0.18922280770353972,
#                 0.18332423341833054,
#                 0.18059794115647673,
#                 0.17848075662180782]),
#               ('auc',
#                [0.8311070493100832,
#                 0.8970469437213895,
#                 0.9022855790650423,
#                 0.9124609346312964,
#                 0.9192581047890266,
#                 0.921122634658224,
#                 0.9228362069668954,
#                 0.9241009865280577,
#                 0.9342885818965165,
#                 0.9348312131275959]),
#               ('misclassified',
#                [99.0,
#                 108.0,
#                 86.0,
#                 87.0,
#                 77.0,
#                 67.0,
#                 72.0,
#                 65.0,
#                 63.0,
#                 63.0])]),
#  'train': OrderedDict([('logloss',
#                [0.4260565614015618,
#                 0.31924544109380454,
#                 0.2615447266740294,
#                 0.23201160395874826,
#                 0.2036987414034271,
#                 0.19083553150438326,
#                 0.1807462363358167,
#                 0.17447118594652888,
#                 0.169280224419656,
#                 0.165865333413524]),
#               ('auc',
#                [0.8347414480092087,
#                 0.8884219769192173,
#                 0.8956162746081875,
#                 0.9012529146129099,
#                 0.9086929252383341,
#                 0.9114717688379917,
#                 0.9145369085918361,
#                 0.916860482276202,
#                 0.9338080340013577,
#                 0.9375084855818896]),
#               ('misclassified',
#                [216.0,
#                 228.0,
#                 179.0,
#                 177.0,
#                 146.0,
#                 125.0,
#                 124.0,
#                 112.0,
#                 112.0,
#                 109.0])])}

# %% [markdown]
# ## Ранняя остановка
# **Ранняя остановка используется для того, чтобы прекратить обучение модели, если ошибка за несколько итераций не уменьшилась.**

# %%
params["eval_metric"] = "error"
num_rounds = 1500

xgb_model = xgb.train(params, dtrain, num_rounds, watchlist, early_stopping_rounds=10)
# Out:
# [22:08:57] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	test-error:0.10000	train-error:0.09130
# [1]	test-error:0.09000	train-error:0.08830
# [2]	test-error:0.07300	train-error:0.06772
# [3]	test-error:0.06700	train-error:0.06044
# [4]	test-error:0.05800	train-error:0.04629
# [5]	test-error:0.05600	train-error:0.04972
# [6]	test-error:0.05700	train-error:0.04629
# [7]	test-error:0.05600	train-error:0.04329
# [8]	test-error:0.05200	train-error:0.04415
# [9]	test-error:0.05300	train-error:0.04243
# [10]	test-error:0.05700	train-error:0.04201
# [11]	test-error:0.05500	train-error:0.04158
# [12]	test-error:0.05200	train-error:0.04029
# [13]	test-error:0.05400	train-error:0.03943
# [14]	test-error:0.05100	train-error:0.03986
# [15]	test-error:0.05400	train-error:0.03943
# [16]	test-error:0.05300	train-error:0.03515
# [17]	test-error:0.05300	train-error:0.03558
# [18]	test-error:0.05200	train-error:0.03386
# [19]	test-error:0.05500	train-error:0.03258
# [20]	test-error:0.05500	train-error:0.03129
# [21]	test-error:0.05500	train-error:0.03129
# [22]	test-error:0.05200	train-error:0.03172
# [23]	test-error:0.05400	train-error:0.03000
# [24]	test-error:0.05500	train-error:0.03043
# [25]	test-error:0.05200	train-error:0.03043
# [26]	test-error:0.05100	train-error:0.02872
# [27]	test-error:0.05100	train-error:0.02829
# [28]	test-error:0.05100	train-error:0.02786
# [29]	test-error:0.05200	train-error:0.02786
# [30]	test-error:0.05000	train-error:0.02743
# [31]	test-error:0.04900	train-error:0.02743
# [32]	test-error:0.05000	train-error:0.02700
# [33]	test-error:0.05200	train-error:0.02615
# [34]	test-error:0.05100	train-error:0.02529
# [35]	test-error:0.05000	train-error:0.02529
# [36]	test-error:0.05100	train-error:0.02529
# [37]	test-error:0.04900	train-error:0.02572
# [38]	test-error:0.05000	train-error:0.02486
# [39]	test-error:0.04900	train-error:0.02486
# [40]	test-error:0.04800	train-error:0.02486
# [41]	test-error:0.04900	train-error:0.02486
# [42]	test-error:0.04700	train-error:0.02486
# [43]	test-error:0.04900	train-error:0.02529
# [44]	test-error:0.04500	train-error:0.02443
# [45]	test-error:0.04700	train-error:0.02443
# [46]	test-error:0.04800	train-error:0.02315
# [47]	test-error:0.04800	train-error:0.02272
# [48]	test-error:0.05000	train-error:0.02315
# [49]	test-error:0.04700	train-error:0.02229
# [50]	test-error:0.04700	train-error:0.02143
# [51]	test-error:0.04800	train-error:0.02186
# [52]	test-error:0.04600	train-error:0.02100
# [53]	test-error:0.04500	train-error:0.02143
# [54]	test-error:0.04500	train-error:0.02143
# [55]	test-error:0.04500	train-error:0.02057
# [56]	test-error:0.04500	train-error:0.02057
# [57]	test-error:0.04300	train-error:0.01929
# [58]	test-error:0.04300	train-error:0.01972
# [59]	test-error:0.04400	train-error:0.01972
# [60]	test-error:0.04500	train-error:0.01886
# [61]	test-error:0.04400	train-error:0.01843
# [62]	test-error:0.04600	train-error:0.01715
# [63]	test-error:0.04600	train-error:0.01629
# [64]	test-error:0.04800	train-error:0.01672
# [65]	test-error:0.04700	train-error:0.01672
# [66]	test-error:0.04700	train-error:0.01629
# [67]	test-error:0.04700	train-error:0.01543
# [68]	test-error:0.04900	train-error:0.01543
# [69]	test-error:0.04700	train-error:0.01543
# [70]	test-error:0.04700	train-error:0.01543
# [71]	test-error:0.04600	train-error:0.01543
# [72]	test-error:0.04700	train-error:0.01414
# [73]	test-error:0.04700	train-error:0.01372
# [74]	test-error:0.04700	train-error:0.01243
# [75]	test-error:0.04900	train-error:0.01157
# [76]	test-error:0.04800	train-error:0.01029
# [77]	test-error:0.04800	train-error:0.00986
# [78]	test-error:0.04900	train-error:0.00986
# [79]	test-error:0.05100	train-error:0.00986
# [80]	test-error:0.05200	train-error:0.00986
# [81]	test-error:0.05200	train-error:0.00943
# [82]	test-error:0.05100	train-error:0.00943
# [83]	test-error:0.05300	train-error:0.01029
# [84]	test-error:0.05000	train-error:0.00814
# [85]	test-error:0.05000	train-error:0.00814
# [86]	test-error:0.05000	train-error:0.00814
# [87]	test-error:0.05000	train-error:0.00857
# [88]	test-error:0.04600	train-error:0.00772
# [89]	test-error:0.04800	train-error:0.00772
# [90]	test-error:0.04800	train-error:0.00729
# [91]	test-error:0.04700	train-error:0.00686
# [92]	test-error:0.04700	train-error:0.00600
# [93]	test-error:0.04700	train-error:0.00514
# [94]	test-error:0.04700	train-error:0.00514
# [95]	test-error:0.04700	train-error:0.00514
# [96]	test-error:0.04600	train-error:0.00557
# [97]	test-error:0.04800	train-error:0.00557
# [98]	test-error:0.04900	train-error:0.00557
# [99]	test-error:0.04800	train-error:0.00557
# [100]	test-error:0.04900	train-error:0.00471
# [101]	test-error:0.05000	train-error:0.00429
# [102]	test-error:0.04900	train-error:0.00386
# [103]	test-error:0.05100	train-error:0.00386
# [104]	test-error:0.05000	train-error:0.00386
# [105]	test-error:0.05100	train-error:0.00386
# [106]	test-error:0.05100	train-error:0.00386
# [107]	test-error:0.05200	train-error:0.00300
# [108]	test-error:0.04900	train-error:0.00300
# [109]	test-error:0.04900	train-error:0.00300
# [110]	test-error:0.05000	train-error:0.00257
# [111]	test-error:0.04800	train-error:0.00214
# [112]	test-error:0.04800	train-error:0.00214
# [113]	test-error:0.05000	train-error:0.00257
# [114]	test-error:0.05000	train-error:0.00214
# [115]	test-error:0.05000	train-error:0.00214
# [116]	test-error:0.05000	train-error:0.00171
# [117]	test-error:0.04900	train-error:0.00129
# [118]	test-error:0.04700	train-error:0.00129
# [119]	test-error:0.04900	train-error:0.00129
# [120]	test-error:0.04700	train-error:0.00129
# [121]	test-error:0.04700	train-error:0.00129
# [122]	test-error:0.04700	train-error:0.00086
# [123]	test-error:0.04700	train-error:0.00086
# [124]	test-error:0.04800	train-error:0.00086
# [125]	test-error:0.04800	train-error:0.00086
# [126]	test-error:0.04800	train-error:0.00086
# [127]	test-error:0.04800	train-error:0.00086
# [128]	test-error:0.04700	train-error:0.00086
# [129]	test-error:0.04700	train-error:0.00086
# [130]	test-error:0.04700	train-error:0.00086
# [131]	test-error:0.04900	train-error:0.00086

# %%
params["eval_metric"]
# Out:
# 'error'

# %%
print("Booster best train score: {}".format(xgb_model.best_score))
print("Booster best iteration: {}".format(xgb_model.best_iteration))
# Out:
# Booster best train score: 0.00085726532361766
# Booster best iteration: 122

# %% [markdown]
# ## Кросс-валидация с Xgboost
# **Продемонстрируем функцию xgboost.cv.**

# %%
num_rounds = 10
hist = xgb.cv(params, dtrain, num_rounds, nfold=10, metrics={"error"}, seed=42)
hist
# Out:
# [22:11:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [22:11:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [22:11:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [22:11:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [22:11:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [22:11:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [22:11:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [22:11:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [22:11:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [22:11:45] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#    train-error-mean  train-error-std  test-error-mean  test-error-std
# 0          0.095156         0.006252         0.101587        0.016502
# 1          0.087727         0.004761         0.093436        0.013484
# 2          0.072486         0.006521         0.087871        0.013049
# 3          0.055294         0.004470         0.069000        0.011660
# 4          0.047578         0.004258         0.060012        0.010868
# 5          0.046911         0.003211         0.057876        0.010774
# 6          0.042721         0.003302         0.055297        0.008692
# 7          0.041196         0.003075         0.056152        0.010409
# 8          0.039768         0.002707         0.057010        0.009981
# 9          0.038768         0.002038         0.054008        0.009813

# %% [markdown]
# Замечания:
#
# - по умолчанию на выходе DataFrame (можно поменять параметр `as_pandas`),
# - метрики передатся как параметр (можно и несколько),
# - можно использовать и свои метрики (параметры `feval` и `maximize`),
# - можно также использовать раннюю остановку ( `early_stopping_rounds`)
